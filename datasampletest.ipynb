# %%
#import libraries
import pandas as pd
import os

# %%
#import libraries
from matplotlib import pyplot as plt

# %%
# gak ada hubungannya sama sample, nyoba doang
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y, z")
plt.legend(["y", "z"])
plt.show()

# %%
sample = pd.read_csv("hotel_bookings.csv")

# %%
sample
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
sample.arrival_date_year
# Out:
# 0         2015
# 1         2015
# 2         2015
# 3         2015
# 4         2015
#           ...
# 119385    2017
# 119386    2017
# 119387    2017
# 119388    2017
# 119389    2017
# Name: arrival_date_year, Length: 119390, dtype: int64

# %%
sample.lead_time
# Out:
# 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 119390, dtype: int64

# %%
sample15 = sample[sample.arrival_date_year == 2015]
sample15
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 82958     City Hotel            0          4               2015
# 82959     City Hotel            0          0               2015
# 82960     City Hotel            0          1               2015
# 82974     City Hotel            0          0               2015
# 103758    City Hotel            0          0               2015
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...
